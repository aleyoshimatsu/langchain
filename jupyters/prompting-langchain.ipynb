# %% [markdown]
# # Prompting Langchain

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:720/format:webp/1*DkgQ23ng-8J2sl66_YQWnw.png">

# %%
from typing import List
# !pip install langchain-openai
# !pip install langchain
# !pip install langchain_community
# !pip install langchain_core
# !pip install gradio
# !pip install unstructured
# !pip install unstructured[pdf]
# !pip install Chromadb
# !pip install numpy==1.24.1py
# !pip install langdetect
# Out:
# Requirement already satisfied: langchain-openai in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (0.1.7)
# Requirement already satisfied: langchain-core<0.3,>=0.1.46 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-openai) (0.1.52)
# Requirement already satisfied: openai<2.0.0,>=1.24.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-openai) (1.30.3)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (0.1.63)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (2.9.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (8.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (3.6.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (0.27.2)
# Requirement already satisfied: sniffio in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (4.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.24.0->langchain-openai) (3.4)
# Requirement already satisfied: certifi in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.46->langchain-openai) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.3,>=0.1.46->langchain-openai) (3.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.46->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain-core<0.3,>=0.1.46->langchain-openai) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.2)
# Requirement already satisfied: langchain in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (0.1.20)
# Requirement already satisfied: PyYAML>=5.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (1.4.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (0.6.6)
# Requirement already satisfied: langchain-community<0.1,>=0.0.38 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (0.0.38)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.52 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (0.1.63)
# Requirement already satisfied: numpy<2,>=1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (1.23.5)
# Requirement already satisfied: pydantic<3,>=1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (2.9.1)
# Requirement already satisfied: requests<3,>=2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (2.23.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain) (2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: langchain_community in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (0.0.38)
# Requirement already satisfied: PyYAML>=5.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_community) (1.4.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_community) (0.6.6)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.52 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_community) (0.1.52)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_community) (0.1.63)
# Requirement already satisfied: numpy<2,>=1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_community) (1.23.5)
# Requirement already satisfied: requests<3,>=2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.19.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain_community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain_community) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain_community) (2.9.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (2.0.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain_community) (2.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.52->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.52->langchain_community) (2.23.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.52->langchain_community) (4.12.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: langchain_core in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (0.1.52)
# Requirement already satisfied: PyYAML>=5.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_core) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_core) (0.1.63)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_core) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_core) (2.9.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langchain_core) (8.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_core) (3.10.3)
# Requirement already satisfied: requests<3,>=2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_core) (2.32.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain_core) (2.23.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic<3,>=1->langchain_core) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain_core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain_core) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain_core) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain_core) (2024.8.30)
# Requirement already satisfied: gradio in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (4.43.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (3.6.2)
# Requirement already satisfied: fastapi<0.113.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (0.112.4)
# Requirement already satisfied: ffmpy in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (0.24.6)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (5.12.0)
# Requirement already satisfied: jinja2<4.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (3.7.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (1.23.5)
# Requirement already satisfied: orjson~=3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (3.10.3)
# Requirement already satisfied: packaging in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (1.5.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (2.9.1)
# Requirement already satisfied: pydub in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (0.6.4)
# Requirement already satisfied: semantic-version~=2.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (4.12.0)
# Requirement already satisfied: urllib3~=2.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (2.2.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio) (0.30.6)
# Requirement already satisfied: fsspec in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio-client==1.3.0->gradio) (2024.9.0)
# Requirement already satisfied: websockets<13.0,>=10.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from gradio-client==1.3.0->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from anyio<5.0,>=3.0->gradio) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from fastapi<0.113.0->gradio) (0.38.5)
# Requirement already satisfied: certifi in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (3.8.0)
# Requirement already satisfied: requests in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.5)
# Requirement already satisfied: zipp>=3.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from importlib-resources<7.0,>=1.3->gradio) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio) (2022.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic>=2.0->gradio) (2.23.3)
# Requirement already satisfied: click>=8.0.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio) (8.1.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: six>=1.5 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.2)
# Requirement already satisfied: mdurl~=0.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: unstructured in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (0.15.9)
# Requirement already satisfied: chardet in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (5.0.0)
# Requirement already satisfied: filetype in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (4.9.1)
# Requirement already satisfied: nltk in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: tabulate in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: requests in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (4.11.1)
# Requirement already satisfied: emoji in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (2.12.1)
# Requirement already satisfied: dataclasses-json in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (0.6.6)
# Requirement already satisfied: python-iso639 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (2024.4.27)
# Requirement already satisfied: langdetect in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy<2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (1.23.5)
# Requirement already satisfied: rapidfuzz in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (3.9.7)
# Requirement already satisfied: backoff in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (4.12.0)
# Requirement already satisfied: unstructured-client in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (0.25.7)
# Requirement already satisfied: wrapt in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (1.14.1)
# Requirement already satisfied: tqdm in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (4.66.5)
# Requirement already satisfied: psutil in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (5.9.4)
# Requirement already satisfied: python-oxmsg in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured) (0.0.1)
# Requirement already satisfied: soupsieve>1.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from beautifulsoup4->unstructured) (2.3.2.post1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from dataclasses-json->unstructured) (3.19.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: click in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from nltk->unstructured) (8.1.3)
# Requirement already satisfied: joblib in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from nltk->unstructured) (2024.5.15)
# Requirement already satisfied: olefile in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests->unstructured) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests->unstructured) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests->unstructured) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests->unstructured) (2024.8.30)
# Requirement already satisfied: deepdiff>=6.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured-client->unstructured) (8.0.1)
# Requirement already satisfied: httpx>=0.27.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured-client->unstructured) (0.27.2)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: packaging>=23.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured-client->unstructured) (23.2)
# Requirement already satisfied: pypdf>=4.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured-client->unstructured) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured-client->unstructured) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: orderly-set==5.2.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from deepdiff>=6.0->unstructured-client->unstructured) (5.2.2)
# Requirement already satisfied: anyio in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (3.6.2)
# Requirement already satisfied: httpcore==1.* in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.5)
# Requirement already satisfied: sniffio in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# zsh:1: no matches found: unstructured[pdf]
# Requirement already satisfied: Chromadb in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (0.5.5)
# Requirement already satisfied: build>=1.0.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (1.2.2)
# Requirement already satisfied: pydantic>=1.9 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (2.9.1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (0.112.4)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (0.30.6)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (1.23.5)
# Requirement already satisfied: posthog>=2.4.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (3.6.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (4.12.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (5.12.0)
# Requirement already satisfied: grpcio>=1.58.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (1.66.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (3.10.3)
# Requirement already satisfied: httpx>=0.27.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from Chromadb) (0.27.2)
# Requirement already satisfied: packaging>=19.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from build>=1.0.3->Chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from build>=1.0.3->Chromadb) (1.1.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from build>=1.0.3->Chromadb) (8.4.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from build>=1.0.3->Chromadb) (2.0.1)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from fastapi>=0.95.2->Chromadb) (0.38.5)
# Requirement already satisfied: anyio in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx>=0.27.0->Chromadb) (3.6.2)
# Requirement already satisfied: certifi in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx>=0.27.0->Chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx>=0.27.0->Chromadb) (1.0.5)
# Requirement already satisfied: idna in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx>=0.27.0->Chromadb) (3.4)
# Requirement already satisfied: sniffio in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpx>=0.27.0->Chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->Chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->Chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->Chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->Chromadb) (2.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->Chromadb) (1.8.0)
# Requirement already satisfied: requests in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->Chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->Chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->Chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->Chromadb) (2.2.2)
# Requirement already satisfied: coloredlogs in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->Chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->Chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->Chromadb) (3.20.3)
# Requirement already satisfied: sympy in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->Chromadb) (1.13.2)
# Requirement already satisfied: deprecated>=1.2.6 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->Chromadb) (1.2.13)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->Chromadb) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->Chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->Chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (58.1.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->Chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from posthog>=2.4.0->Chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from posthog>=2.4.0->Chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic>=1.9->Chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pydantic>=1.9->Chromadb) (2.23.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from tokenizers>=0.13.2->Chromadb) (0.24.6)
# Requirement already satisfied: click>=8.0.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from typer>=0.9.0->Chromadb) (8.1.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from typer>=0.9.0->Chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from typer>=0.9.0->Chromadb) (13.7.1)
# Requirement already satisfied: httptools>=0.5.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (0.21.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (0.20.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->Chromadb) (12.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from importlib-resources->Chromadb) (3.10.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->Chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->Chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->Chromadb) (4.9)
# Requirement already satisfied: filelock in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->Chromadb) (3.8.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->Chromadb) (2024.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from requests->kubernetes>=28.1.0->Chromadb) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from rich>=10.11.0->typer>=0.9.0->Chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from rich>=10.11.0->typer>=0.9.0->Chromadb) (2.13.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->Chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->Chromadb) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->Chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->Chromadb) (0.6.0)
# ERROR: Invalid requirement: 'numpy==1.24.1py': Expected end or semicolon (after version specifier)
#     numpy==1.24.1py
#          ~~~~~~~~^
# Requirement already satisfied: langdetect in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (1.0.9)
# Requirement already satisfied: six in /home/alexandre_pantalena/desenvolvimento/repos/data-pipelines/airflow/airflow_venv/lib/python3.9/site-packages (from langdetect) (1.16.0)

# %%
import os

from langchain_community.document_loaders import UnstructuredFileLoader
from langchain.output_parsers import ResponseSchema, StructuredOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_openai import AzureOpenAIEmbeddings, AzureChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain.chains.qa_with_sources import load_qa_with_sources_chain
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain.vectorstores import Chroma
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.schema.runnable import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import (
    ChatPromptTemplate,
    FewShotChatMessagePromptTemplate,
)
from operator import itemgetter
from langdetect import detect, detect_langs

# %%
# file = 'CRA023005V5-ASS28082024V01-000727267.pdf'
# file = '118498.pdf'
file = '573735.pdf'

encoding_name="cl100k_base"
path_faiss="/tmp/faiss_index"
deployment_name = "leitura_documento_gpt4o"
embedding_model = "text-embedding"
openai_api_version="2023-05-15"
chunk_size = 1024
chunk_overlap = 256

model = "gpt-4o"

verbose=False
temperature = 0
k = 5
fetch_k = 20

# %% [markdown]
# # Loading doc using Unstructured-IO

# %%
print("Loading Unstructured Data")
# modes: “single”, “elements”, and “paged”
# loader = UnstructuredFileLoader(pdf, mode="elements")
loader = UnstructuredFileLoader(file, mode="paged", strategy="fast")
raw_doc = loader.load()
raw_doc
# Out:
# Loading Unstructured Data
# [Document(page_content='TERMO DE SECURITIZAÇÃO DE DIREITOS CREDITÓRIOS DO AGRONEGÓCIO\n\npara emissão de\n\nCERTIFICADOS DE RECEBÍVEIS DO AGRONEGÓCIO DA 1ª E 2ª SÉRIES DA 34ª (TRIGÉSIMA QUARTA) EMISSÃO DA\n\nCERES SECURITIZADORA S.A. como companhia securitizadora\n\nlastreados em direitos creditórios do agronegócio devidos pela NATIVA AGRONEGÓCIOS LTDA.\n\ncelebrado com\n\nOLIVEIRA TRUST DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS S.A. como agente fiduciário\n\nDatado de 18 de dezembro de 2023\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 1, 'filetype': 'application/pdf', 'parent_id': 'efb6bc7732c491d63c9ab702b264530a'}),
#  Document(page_content='TERMO DE SECURITIZAÇÃO DE DIREITOS CREDITÓRIOS DO AGRONEGÓCIO PARA EMISSÃO DE CERTIFICADOS DE RECEBÍVEIS DO AGRONEGÓCIO, DA 1ª E 2ª SÉRIES, DA 34ª (TRIGÉSIMA QUARTA) EMISSÃO DA CERES SECURITIZADORA S.A., LASTREADOS EM DIREITOS CREDITÓRIOS DO AGRONEGÓCIO DEVIDOS PELA NATIVA AGRONEGÓCIOS LTDA.\n\nPelo presente instrumento particular:\n\nA.\n\nCERES SECURITIZADORA S.A., companhia securitizadora, registrada na Comissão de Valores Mobiliários (“CVM”), na categoria “S1”, com sede na Cidade de Uberaba, Estado de Minas Gerais, na Avenida Edilson Lamartine n.º 536, Pavimento Superior, Sala 2, Parque das Américas, CEP 38.045-000, inscrita no CNPJ sob n.º 41.534.746/0001-62, neste ato representada na forma de seu estatuto social (“Securitizadora”); e\n\nB.\n\nOLIVEIRA TRUST DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS S.A., sociedade por ações, com filial na Cidade de São Paulo, Estado de São Paulo, na Rua Joaquim Floriano n.º 1.052, 13º andar, Sala 132, Itaim Bibi, CEP 04534-004, inscrita no CNPJ sob o nº 36.113.876/0004-34, neste ato representada na forma de seu estatuto social (“Agente Fiduciário”), na qualidade de agente fiduciário nomeado nos termos do artigo 25, inciso III, da Lei 14.430 e da Resolução CVM nº 17, conforme abaixo definidas:\n\nfirmam o presente “Termo de Securitização de Direitos Creditórios do Agronegócio para Emissão de Certificados de Recebíveis do Agronegócio, da 1ª e 2ª Séries, da 34ª (Trigésima Quarta) Emissão da Ceres Securitizadora S.A., Lastreados em Direitos Creditórios do Agronegócio Devidos pela Nativa Agronegócios Ltda.” de acordo com o artigo 25 da Lei n.º 14.430, de 3 de agosto de 2022, conforme em vigor (“Lei 14.430”), e com a Resolução n.º 60, da CVM, de 23 de dezembro de 2021, conforme em vigor (“Resolução CVM 60”), para formalizar a securitização de Direitos Creditórios do Agronegócio (conforme abaixo definido) e a correspondente emissão de certificados de recebíveis do agronegócio pela Emissora, de acordo com as seguintes cláusulas e condições.\n\nI.\n\nCLÁUSULAS\n\n1.\n\nDEFINIÇÕES E REGRAS DE INTERPRETAÇÃO\n\n1.1. Definições: Exceto se expressamente indicado, palavras e expressões em maiúsculas, não definidas neste. Termo de Securitização, terão o significado previsto abaixo ou nos demais Documentos da Operação (abaixo definido)\n\n“Agente de Formalização e Cobrança”:\n\nsignifica a CERES INVESTIMENTOS E CONSULTORIA LTDA., sociedade empresária limitada, com sede na Cidade de Uberaba, Estado de Minas Gerais, na Avenida Edilson Lamartine Mendes n.º 536, Parque das Américas, o CEP 38.045-000, n.º 34.250.750/0001-33.\n\ninscrita\n\nno\n\nCNPJ\n\nsob\n\n2\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 2, 'parent_id': 'c40703437f59fad918b1ba370d16d8d2', 'filetype': 'application/pdf'}),
#  Document(page_content='“Agente Fiduciário”:\n\n“Agente Liquidante”:\n\n“Agente Registrador dos CRA”: “Agente Registrador do Lastro”:\n\n“Amortização Extraordinária”:\n\n“Amortização Extraordinária Obrigatória dos CDCA”:\n\n“ANBIMA”:\n\n“Anexos”:\n\n“Anúncio de Encerramento da Distribuição”:\n\n“Anúncio de Início da Distribuição”:\n\n“Assembleia de Titulares de CRA”:\n\nsignifica a OLIVEIRA TRUST DISTRIBUIDORA DE TÍTULOS E conforme qualificada VALORES MOBILIÁRIOS S.A., anteriormente. significa a VÓRTX DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS LTDA., instituição financeira com sede na Cidade de São Paulo, Estado de São Paulo, na Rua Gilberto Sabino, nº 215, 4º andar, Pinheiros, CEP 05425-020, inscrita no CNPJ nº 22.610.500/0001-88. significa a CERES SECURITIZADORA S.A., conforme qualificada anteriormente. significa a VÓRTX DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS LTDA., conforme qualificada anteriormente. significa a amortização extraordinária do saldo do Valor Nominal Unitário dos CRA, em virtude da ocorrência das hipóteses previstas nas Cláusulas 8.2 e 8.4 dos CDCA. significa a obrigação da Devedora efetuar a amortização extraordinária dos CDCA mediante o pagamento total dos CDCA, nos termos da Cláusula 8.3 dos CDCA. significa a ASSOCIAÇÃO BRASILEIRA DAS ENTIDADES DOS MERCADOS FINANCEIRO E DE CAPITAIS, pessoa jurídica de direito privado, com sede na Cidade de Rio de Janeiro, Estado de Rio de Janeiro, na Avenida República do Chile n.º 230, 13º andar, CEP 20.031-170, inscrita no CNPJ sob o n.º 34.271.171/0001-77. significa os anexos ao presente Termo de Securitização, cujos termos são parte integrante e complementar deste Termo de Securitização, para todos os fins e efeitos de direito. significa, nos termos do artigo 76 da Resolução CVM 160, o anúncio de divulgação do resultado da Oferta, a ser disponibilizado na página da rede mundial de computadores: (i) da Securitizadora; (ii) do Coordenador Líder; (iii) da B3; e (iv) da CVM, tão logo se verifique o primeiro entre os seguintes eventos: (a) encerramento do prazo estipulado para a Oferta; ou (b) distribuição da totalidade dos CRA. significa, nos termos do §3º do artigo 59 da Resolução CVM 160, o aviso resumido que comunica o início da distribuição da Oferta, a ser disponibilizado na página da rede mundial de computadores: (i) da Securitizadora; (ii) do Coordenador Líder; (iii) da B3; e (iv) da CVM. significa a assembleia especial de titulares de CRA em Circulação, realizada na forma da Cláusula 14 deste Termo de Securitização.\n\n3\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 3, 'filetype': 'application/pdf', 'parent_id': '54cafaf303dcefe1e85d96de9f037237'}),
#  Document(page_content='“Auditor Independente”:\n\n“Aviso ao Mercado”:\n\n“Aval”:\n\n“Avalistas”:\n\n“B3”:\n\nsignifica a BLB AUDITORES INDEPENDENTES, com sede na cidade de Ribeirão Preto, Estado de São Paulo, na Avenida Presidente Vargas, nº 2.121, 6º andar, conjunto 603, Jardim América, CEP 14024-260, inscrita no CNPJ sob o nº 06.096.033/0001-63, auditor independente contratado pela Emissora para auditar as demonstrações financeiras do Patrimônio Separado em conformidade com o disposto na Lei das Sociedades por Ações e na Resolução CVM 60. significa, nos termos do §1º do artigo 57 da Resolução CVM 160, o aviso resumido que dá ampla divulgação ao requerimento do registro automático da Oferta na CVM, a ser disponibilizado na página da rede mundial de computadores: (i) da Securitizadora; (ii) do Coordenador Líder; (iii) da B3; e (iv) da CVM. significa a garantia fidejussória representada por aval prestada pelos Avalistas no âmbito dos CDCA, por meio da qual os Avalistas se tornaram devedores solidários e principais pagadores, juntamente com a Devedora, perante a Emissora, para o adimplemento das Obrigações Garantidas, bem como para o cumprimento das demais obrigações neles previstas. Significa, em conjunto, EDERSON PILONETTO, brasileiro, contador, casado em comunhão parcial de bens, portador do RG n.º 6.251.539-2, expedido pela SSP/PR, inscrito no CPF sob o n.º 941.170.719-04, com endereço comercial na Rua Colonizador Ênio Pipino, 4905, Setor Industrial Norte, Sinop, MT, CEP 78.550-528; ADRIANO DA SILVA CAMPOS, brasileiro, técnico em agropecuária, casado com separação total de bens, portador do RG n.º MG12020264, expedido pela SSP/MG, inscrito no CPF sob o n.º 045.063.786-79, com endereço comercial na Rua Colonizador Ênio Pipino, 4905, Setor Industrial Norte, Sinop, MT, CEP 78.550-528; e SILVIO VALDIR KAFER, brasileiro, técnico em agropecuária, comunhão universal de bens, portador do RG n.º 10R2404509, expedido pela SSP/SC, inscrito no CPF sob o n.º 833.029.219-34, com endereço comercial na Rua Colonizador Ênio Pipino, 4905, Setor Industrial Norte, Sinop, MT, CEP 78.550-528. significa a B3 – BRASIL, BOLSA, BALCÃO, instituição devidamente autorizada pelo Banco Central do Brasil para a prestação de serviços de depositária de ativos escriturais e liquidação financeira, com sede na Cidade de São Paulo, Estado de São Paulo, na Praça Antônio Prado n.º 48, 7º\n\n4\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 4, 'filetype': 'application/pdf', 'parent_id': '6ab4c631b8a38d3bd72b68cc000d5cc5'}),
#  Document(page_content='“Boletim de Subscrição de CRA Sênior”:\n\n“Boletim de Subscrição de CRA Subordinados”:\n\n“Boletins de Subscrição”:\n\n“CDCA”:\n\n“CDCA-A”:\n\n“CDCA-B”:\n\n“CERC”:\n\n“Cessão Fiduciária”:\n\nandar, CEP 01.010-901, inscrita no CNPJ sob o n.º 09.346.601/0001-25. significa os boletins de subscrição de CRA Sênior, por meio do qual os Investidores Profissionais subscreverão os CRA Sênior e formalizarão sua adesão aos termos e condições deste Termo de Securitização. significa os boletins de subscrição dos CRA Subordinados, por meio do qual a Devedora subscreverá os CRA Subordinados, que serão integralizados por meio da cessão de Direitos Creditórios do Agronegócio em Garantia, observado o disposto no respectivo Termo de Cessão, em montante proporcional ao valor dos CRA Subordinados, e formalizará sua adesão aos termos e condições deste Termo de Securitização. significa o Boletim de Subscrição de CRA Sênior e o Boletim de Subscrição de CRA Subordinados, quando referidos em conjunto. significa, quando em conjunto, o (i) CDCA-A; e o (ii) CDCA- B, ambos emitidos pela Devedora em favor da Emissora, de acordo com a Lei 11.076, e cuja identificação e características estão indicadas no Anexo I deste Termo de Securitização. significa o “Certificado de Direitos Creditórios do Agronegócio n.º 001/2023”, emitido pela Devedora em favor da Emissora, nos termos da Lei 11.076, cujos direitos creditórios serão vinculados aos CRA Sênior, no âmbito da Operação de Securitização. significa o “Certificado de Direitos Creditórios do Agronegócio n.º 001/2023”, emitido pela Devedora em favor da Emissora, nos termos da Lei 11.076, cujos direitos creditórios serão vinculados aos CRA Subordinado, no âmbito da Operação de Securitização. significa a CERC CENTRAL DE RECEBÍVEIS S.A., sociedade por ações, com sede na Cidade de São Paulo, Estado de São Paulo, na Avenida Paulista nº 37, 6º andar, conjunto 62, Bela Vista, CEP 01.311-902, inscrita no CNPJ sob o nº 23.399.607/0001-91. significa a garantia a ser constituída nos termos do Contrato de Cessão Fiduciária, nos termos dos artigos 18 a 20, da Lei 9.514, o artigo 66-B da Lei nº 4.728, de 14 de julho de 1965, conforme em vigor, do artigo 1.361 e seguintes do Código Civil, e dos artigos 33 e 41 da Lei 11.076, por meio da qual os Títulos e/ou Recebíveis serão cedidas integral fiduciariamente em garantia do pontual e\n\n5\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 5, 'filetype': 'application/pdf', 'parent_id': 'a3834c2e0df9466c9169aa23b98ddc8b'}),
#  Document(page_content='“CETIP21”:\n\n“Clientes”:\n\n“CNPJ”:\n\n“Código ANBIMA”:\n\n“Código Civil”:\n\n“Código de Processo Civil”:\n\n“COFINS”:\n\n“Condições Precedentes”:\n\n“Condições Precedente de Desembolso”:\n\n“Condições Precedentes de Aquisição”:\n\n“Conta Autorizada Devedora”:\n\n“Conta Centralizadora”:\n\npagamento dos CDCA, observadas as hipóteses de Opção de Recomposição de Garantia, Opção de Substituição de Garantia e Obrigação de Recomposição de Garantia, observado que, após a Data Limite de Constituição, a Cessão Fiduciária deverá observar o Valor Mínimo de Garantia, nos termos previstos no Contrato de Cessão Fiduciária. significa o módulo CETIP21 – Títulos e Valores Mobiliários, administrado e operacionalizado pela B3. significa as pessoas físicas ou pessoas jurídicas adquirentes dos Insumos comercializados pela Devedora, devedores dos Títulos e dos Recebíveis. significa o “Cadastro de Pessoas Físicas do Ministério da Fazenda”. significa o “Código ANBIMA para Ofertas Públicas”, conforme em vigor. significa a Lei nº 10.406, de 10 de janeiro de 2002, conforme em vigor. significa a Lei nº 13.105, de 16 de março de 2015, conforme alterada. significa a “Contribuição para o Financiamento da Seguridade Social”. significa, quando referidas em conjunto e indistintamente, as Condições Precedentes de Aquisição e as Condições Precedentes de Desembolso. significa as condições necessárias para o desembolso do Preço de Aquisição, pela Securitizadora, em favor da Devedora, conforme disposto na Cláusula 9.3 dos CDCA. significa as condições necessárias para a aquisição dos CDCA pela Securitizadora, conforme disposto na Cláusula 9.2 dos CDCA. significa a conta corrente de titularidade da Devedora mantida no Banco do Brasil, sob o nº 58903-9, agência nº 4205-6, movimentada exclusivamente pela Devedora, na qual serão realizados os pagamentos do Preço de Aquisição, após cumprida, pela Emitente, as Condições Precedentes de Desembolso, e de todos os demais valores devidos à Devedora no âmbito dos CDCA. significa a conta corrente de titularidade da Securitizadora mantida no Banco Bradesco S.A., sob n.º 446182-7, agência n.º 0264, movimentada exclusivamente pela Securitizadora, todos os recursos na qual serão depositados (a) pertencentes ao Patrimônio Separado; e (b) quaisquer outros recursos legitimamente recebidos relacionados à\n\n6\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 6, 'filetype': 'application/pdf', 'parent_id': 'b4e3e013666393b61d9126f128ff5494'}),
#  Document(page_content='“Contrato de Cessão Fiduciária”:\n\n“Contrato de Distribuição”:\n\n“Contrato de Formalização e Cobrança”:\n\n“Contrato de Prestação de Serviços de Agente Liquidante”:\n\n“Contrato de Prestação de Serviços de Custodiante”:\n\n“Coordenador Líder”:\n\nEmissão, manutenção do Fundo de Despesas. significa o “Instrumento Particular de Contrato de Cessão Fiduciária e Promessa de Cessão Fiduciária em Garantia de Direitos Creditórios e Outras Avenças”, a ser celebrado entre a Devedora, a Securitizadora e o Agente de Formalização e Cobrança, por meio do qual a Devedora cederá fiduciariamente os Títulos e os Recebíveis. significa o “Contrato de Coordenação, Colocação e Distribuição Pública, sob Rito Automático de Registro, perante a CVM, de Certificados de Recebíveis do Agronegócio, em Regime de Melhores Esforços de Colocação, da 34ª (Trigésima Quarta) Emissão, da Ceres Securitizadora S.A.”, a ser a ser celebrado entre a Devedora e o Coordenador Líder. significa o “Contrato de Prestação de Serviços de Formalização de Direitos Creditórios do Agronegócio e Cobrança de Direitos Creditórios do Agronegócio Inadimplidos e Outras Avenças”, a ser celebrado entre a Emissora e o Agente de Formalização e Cobrança, por meio do qual o Agente de Formalização e Cobrança foi contratado pela Emissora para realização de emissão de boletos bancários, cobrança extrajudicial e/ou judicial dos Títulos e dos Recebíveis que sejam objeto de cessão fiduciária vencidos e não pagos pelos respectivos Clientes nas respectivas datas de vencimento, observados os procedimentos de cobrança descritos no Contrato de Formalização e Cobrança, bem como a formalização dos Direitos Creditórios do Agronegócio e das Garantias e verificação do atendimento aos Critérios de Elegibilidade dos Títulos e dos Recebíveis que sejam objeto de cessão fiduciária e/ou utilizados para integralização dos CRA Subordinados, conforme o caso. significa o “Instrumento Particular de Contrato de Prestação de Serviços de Agente Liquidante”, a ser celebrado entre a Emissora e o Agente Liquidante, para regular a prestação de serviços de liquidação financeira de certificados de recebíveis do agronegócio de emissão da Emissora, por parte do Agente Liquidante. significa o “Contrato de Prestação de Serviços de Custódia e de Registro de Títulos”, a ser celebrado entre a Emissora e o Custodiante. significa a GUIDE INVESTIMENTOS S.A. CORRETORA DE VALORES, instituição financeira integrante do sistema de\n\nincluindo os recursos para constituição e\n\n7\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 7, 'filetype': 'application/pdf', 'parent_id': '9b7e1884e96241495333bc9eabd7099b'}),
#  Document(page_content='“Correios”:\n\n“CPF”:\n\n“CPR”:\n\n“CRA”:\n\n“CRA em Circulação”:\n\n“CRA Sênior”:\n\n“CRA Subordinados”:\n\n“Critérios de Elegibilidade”:\n\n“CSLL”:\n\ndistribuição de valores mobiliários, com sede na Cidade de São Paulo, Estado de São Paulo, na Avenida Brigadeiro Faria Lima n° 3.064, 12° andar, CEP 01451-000, inscrita no CNPJ sob o nº 65.913.436/0001-17. significa a Empresa Brasileira de Correios e Telégrafos. Significa o Cadastro de Pessoas Físicas do Ministério da Fazenda. significa as cédulas de produto rural, inclusive com previsão de liquidação financeira, emitidas ou a serem emitidas por produtores rurais em favor da Devedora, com garantia de penhor agrícola, devidamente registradas nos cartórios de registro de imóveis competentes, as quais serão objeto da Cessão Fiduciária em garantia das Obrigações Garantidas, nos termos do Contrato de Cessão Fiduciária e devidamente registradas perante a CERC, a B3 ou outra instituição autorizada pelo Banco Central do Brasil a exercer a atividade de registro ou depósito centralizado de ativos financeiros, conforme previsão contratual específica. significa, quando referidos em conjunto, os CRA Sênior e os CRA Subordinado; significa, para fins de constituição de quórum e deste instrumento, a totalidade dos CRA em circulação no mercado, excluídos os CRA Subordinados e aqueles que a Emissora possuir em tesouraria, ou que sejam de propriedade de seus controladores ou de qualquer de suas controladas, ou coligadas, dos fundos de investimento administrados por sociedades integrantes do grupo econômico da Emissora ou que tenham suas carteiras geridas por sociedades integrantes do grupo econômico da Emissora bem como dos respectivos diretores ou conselheiros e respectivos cônjuges. significa os certificados de recebíveis do agronegócio da 1ª (primeira) série da 34ª (trigésima quarta) emissão da Securitizadora. significa os certificados de recebíveis do agronegócio da 2ª (segunda) série da 34ª (trigésima quarta) emissão da Securitizadora. significa os critérios de elegibilidade utilizados para seleção dos Títulos e dos Recebíveis que garantem os Direitos Creditórios do Agronegócio, conforme o caso, os quais serão verificados pelo Agente de Formalização e Cobrança nos termos da Cláusula 4.4 deste Termo de Securitização. significa a Contribuição Social sobre o Lucro Líquido.\n\n8\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 8, 'filetype': 'application/pdf', 'parent_id': '10ba09a36327e5a8006facbbf3f3be80'}),
#  Document(page_content='“Custodiante”:\n\n“CVM”:\n\n“Data de Emissão”:\n\n“Data de Integralização dos CRA”:\n\n“Data de Pagamento da Remuneração dos CRA”\n\n“Data de Vencimento”:\n\n“Data de Vencimento dos Direitos Creditórios do Agronegócio”\n\n“Data Limite de Constituição”:\n\n“Datas de Verificação de Performance”:\n\nsignifica a VÓRTX DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS LTDA., conforme qualificada anteriormente. significa a Comissão de Valores Mobiliários, autarquia federal, vinculada ao Ministério da Fazenda, instituída pela Lei n.º 6.385, de 7 de dezembro de 1976, conforme em vigor. significa a data de emissão dos CRA, qual seja, 18 de dezembro de 2023. significa cada data em que ocorrer a subscrição e integralização dos CRA, à vista, a ser realizada pelos Investidores Profissionais, em moeda corrente nacional, durante o Período de Distribuição, de acordo com os procedimentos da B3. significa as respectivas datas de pagamento da Remuneração dos CRA, conforme descrito nas tabelas constantes do Anexo II a este Termo de Securitização. significa a data de vencimento efetiva dos CRA, qual seja, em 29 de dezembro de 2027. significa a data de vencimento dos Direitos Creditórios do Agronegócio, qual seja, em 30 de setembro de 2027.\n\nsignifica a data limite para a formalização e constituição da Cessão Fiduciária pela Devedora, em valor equivalente, no mínimo, ao Valor Mínimo de Garantia, qual seja, 19 de junho de 2024, observado que este prazo poderá ser prorrogado por 30 (trinta) dias a critério da Emissora, sem a necessidade de aprovação em Assembleia de Titulares de CRA. significa as datas, correspondentes ao 5º (quinto) Dia Útil de cada mês, a partir do mês imediatamente subsequente à primeira Data de Integralização dos CRA, inclusive, em que a Securitizadora verificará, conforme aplicável e com relação ao mês imediatamente anterior, (i) adimplemento do CDCA e quais Títulos e Recebíveis foram devidamente pagos ou inadimplidos; (ii) se o montante de Direitos Creditórios em Garantia Inadimplidos supera o valor dos CRA Subordinados, calculado naquela data; e (v) o Valor Mínimo de Garantia. Para fins de liberação de recursos, conforme previsto nos CDCA, a Securitizadora verificará o Valor Mínimo de Garantia, a seu exclusivo critério, sempre que julgar necessário, para fins de cálculo do montante a ser liberado à Devedora.\n\n9\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 9, 'filetype': 'application/pdf', 'parent_id': 'c101f4dea75a329395fb7fc9546505a3'}),
#  Document(page_content='“Despesas”:\n\n“Despesas de Estruturação”:\n\n“Despesas Recorrentes”:\n\n“Devedora”:\n\n“Dia Útil” ou “Dias Úteis”:\n\n“Direitos Creditórios do Agronegócio”:\n\n“Direitos Creditórios em Garantia”:\n\n“Direitos Creditórios em Garantia Inadimplidos”:\n\n“Documentos Adicionais”:\n\nsignifica as Despesas de Estruturação e as Despesas Recorrentes, quando referidas em conjunto, conforme descritas na Cláusula 15 deste Termo de Securitização. significa as despesas incorridas pela Emissora para na da Oferta, estruturação Cláusula 15.1 deste Termo de Securitização. significa as despesas incorridas pela Emissora para manutenção da estrutura da Oferta, conforme descritas na Cláusula 15.2 deste Termo de Securitização, as quais serão arcadas pelo Fundo de Despesas. significa a NATIVA AGRONEGÓCIOS LTDA., sociedade empresária limitada, com sede na Cidade de Sinop, Estado de Mato Grosso, na Rua Colonizador Enio Pipino, 4905, Setor Industrial Norte, CEP 78.550-528, inscrita no CNPJ sob o n.º 19.092.942/0001-75. significa qualquer dia que não seja sábado, domingo ou dia declarado como feriado nacional, ressalvados os casos cujos pagamentos devam ser realizados por meio da B3, hipótese em que somente será considerado Dia Útil qualquer dia que não seja sábado, domingo ou dia declarado como feriado nacional. Exclusivamente para o cálculo da Remuneração será considerado Dia Útil qualquer dia que não seja sábado, domingo ou dia declarado como feriado nacional. significa agronegócio consubstanciados nos CDCA, identificados no Anexo I a este Termo de Securitização, os quais são caracterizados como direitos creditórios do agronegócio nos termos do §1º, do artigo 23 da Lei 11.076, da Lei 14.430, da Resolução CVM 60 e demais leis e regulamentação aplicáveis, que compõem o lastro dos CRA, aos quais estão vinculados em caráter irrevogável. significa os direitos creditórios decorrentes dos Títulos e dos Recebíveis que sejam de titularidade da Devedora, cedidos fiduciariamente e que venham a ser cedidos fiduciariamente pela Devedora para a Securitizadora por meio do Contrato de Cessão Fiduciária. significa a totalidade dos Direitos Creditórios em Garantia devidos pelo respectivo Cliente caso este venha a apresentar qualquer obrigação vencida e não paga há mais de 90 (noventa) dias contados das respectivas datas de vencimento. significa os documentos adicionais relacionados aos Direitos Creditórios do Agronegócio, que não integram a definição ser: de\n\nconforme\n\ndescritas\n\nos\n\ndireitos\n\ncreditórios\n\ndo\n\nDocumentos\n\nComprobatórios,\n\npodendo\n\n10\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 10, 'filetype': 'application/pdf', 'parent_id': '7b71a8d0ea7a8cd80903dc9d61a3465d'}),
#  Document(page_content='“Documentos Comprobatórios”\n\n“Documentos da Operação”:\n\n“Documentos de Verificação de Negócio”:\n\n“Duplicatas”:\n\n(i) comprovantes de entrega de Insumos à Devedora; (iii) outros (ii) conhecimentos documentos que possam instruir a ação judicial, inclusive, sem limitação, registros contábeis, declaração da Devedora e outros admitidos em juízo. significam os instrumentos utilizados para a formalização, comprovação e evidência dos Direitos Creditórios do Agronegócio e das Garantias, conforme o caso, a saber: (i) os CDCA; (ii) as Notas Promissórias; (iii) o Contrato de Cessão Fiduciária, seus aditamentos, os Termos de Cessão e os Termos de Substituição; (iv) os Títulos; (vi) os instrumentos que formalizam os Recebíveis; e (vi) os Documentos de Verificação de Negócio, sendo obrigação da Devedora e/ou do Custodiante, conforme o caso, mantê-los e/ou guarda-los e enviá-los ao Agente Fiduciário e/ou à Emissora, quando solicitados, em até 5 (cinco) Dias Úteis. significa os documentos relativos à Emissão e à Oferta, conforme em vigor, quais sejam: (i) os Documentos Comprobatórios; (ii) o presente Termo de Securitização; (iii) o Contrato de Formalização e Cobrança; (iv) os Boletins de Subscrição; (v) o Contrato de Distribuição; (vi) o Contrato de Prestação de Serviços de Custodiante; (vii) o Contrato de Prestação de Serviços de Escrituração e Agente Liquidante; (viii) demais contratos com prestadores de serviços celebrados no âmbito da Emissão; (ix) o Anúncio de Início da Distribuição; (x) Anúncio de Encerramento da Distribuição; (xi) o Aviso ao Mercado; e (xii) os respectivos aditamentos e outros instrumentos que venham a ser celebrados e integrem a Oferta. significa os documentos (contratos, títulos de crédito ou outros documentos que formalizem um negócio jurídico), recebimento da mercadoria incluindo canhotos de assinados, que comprovem e demonstrem, de forma razoável, a existência de negócios realizados e a entrega dos Insumos entre a Devedora e os seus clientes, que sejam produtores rurais e/ou cooperativas rurais, exclusivamente relacionados à comercialização de Insumos, em termos de quantidades ser apresentados Títulos e/ou Recebíveis. significa as duplicatas emitidas pela Devedora, com aceite das respectivas pessoas físicas e/ou jurídicas ou, quando sem aceite, que virão acompanhadas da nota fiscal com a via original ou cópia autenticada do canhoto de recebimento da mercadoria assinado, nos termos da Lei 5.474,\n\nde\n\ntransporte;\n\nou\n\ne\n\nvalores,\n\npodendo,\n\ninclusive,\n\n11\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 11, 'filetype': 'application/pdf', 'parent_id': '95b54983d26e6625eb1d59279511c5b4'}),
#  Document(page_content='“Emissão”:\n\n“Emissora” ou “Securitizadora”:\n\n“Empresa de Auditoria”\n\n“Escriturador”:\n\n“Eventos de Liquidação do Patrimônio Separado”:\n\n“Fundo de Despesas”:\n\n“Fundo de Retenção”:\n\ndevidamente registradas perante a CERC, cedidas ou a serem cedidas fiduciariamente pela Devedora nos termos do Contrato de Cessão Fiduciária e/ou utilizadas para integralização dos CRA Subordinados. significa a 34ª (trigésima quarta) emissão dos CRA, em 2 (duas) séries, da Emissora. significa a CERES SECURITIZADORA S.A., conforme qualificada no preâmbulo deste Termo de Securitização. significa a KPMG AUDITORES INDEPENDENTES (CNPJ nº 57.755.217/0001.29). significa a VÓRTX DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS LTDA., acima qualificada. significa os eventos que ensejarão a liquidação do Patrimônio Separado, conforme definidos na Cláusula 10.1 deste Termo de Securitização. significa o fundo composto por um montante constituído com recursos mantidos na Conta Centralizadora e obtidos integralização dos CRA; com (ii) pagamento direto pela Emitente; (iii) o desconto no Preço de Aquisição dos CDCA; ou (iv) recursos do Patrimônio Separado, inicialmente no montante de R$ 1.230.371,00 (um milhão, duzentos e trinta mil e trezentos e setenta e um reais), e a ser recomposto anualmente, no montante equivalente ao Montante Mínimo do Fundo de Despesas, nos termos dos CDCA e deste Termo de Securitização, o qual será utilizado para pagamento das Despesas de Estruturação incorridas durante a vigência dos CRA e para pagamento das Despesas Recorrentes incorridas, conforme descritas na Cláusula 15 deste Termo de Securitização, o qual deverá ser investido em Outros Ativos, devendo, ainda, ser respeitado o Montante Mínimo do Fundo de Despesas, nos termos dos CDCA e deste Termo de Securitização. significa o fundo constituído e mantido, pela Securitizadora, na Conta Centralizadora, com recursos próprios da Devedora ou do Patrimônio Separado, o qual deverá estar 100% (cem por cento) constituído no mês anterior à Data de Pagamento de referência, e será utilizado para provisionamento de recursos para pagamento da parcela de remuneração e amortização imediatamente subsequente dos CRA, de modo que o provisionamento do Fundo de semestralmente, Retenção preferencialmente mediante retenção mensal de 1/6 (um sexto) ao mês dos recursos oriundos do pagamento dos\n\n(i) a\n\nsubscrição e\n\nserá\n\nrecomposto\n\n12\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 12, 'filetype': 'application/pdf', 'parent_id': '51979e6606bc3fdb89e5016aef8b5366'}),
#  Document(page_content='“Garantias”:\n\n“ICP-Brasil”:\n\n“IGP-M”:\n\n“Instituições Autorizadas”:\n\n“Insumos”:\n\n“Investidores Qualificados”: “Investidores Profissionais”: “IOF/Câmbio”:\n\n“IOF/Títulos”:\n\n“IPCA”:\n\n“IRPJ”: “IRRF”: “ISSQN”: “JTF”: “JUCEMG”:\n\n“Legislação Anticorrupção”:\n\nDireitos Creditórios em Garantia, nos termos dos CDCA e deste Termo de Securitização, utilizando-se para tanto, para apuração da remuneração dos CRA Sênior, a Taxa DI apurada para o respectivo mês em que ocorrerá a retenção. significa as garantias vinculadas aos CDCA e constituídas em benefício da Securitizadora para assegurar o pontual e integral pagamento das Obrigações Garantidas, integrantes do Patrimônio Separado, quais sejam, (i) a Cessão Fiduciária; e (ii) o Aval, quando referidos em conjunto. significa a “Infraestrutura de Chaves Públicas Brasileira”. significa o Índice Geral de Preços do Mercado, calculado e divulgado pela Fundação Getúlio Vargas. significa qualquer das seguintes instituições financeiras ou instituição integrante do mesmo grupo econômico, inclusive as administradoras e gestoras de fundos de investimento que possuam, durante toda a vigência dos CDCA e dos CRA, classificação de risco igual ou superior a “AA-(bra)”, em escala nacional, atribuída por agência de classificação de risco evidenciada por meio de relatório público disponível na internet. significa os insumos utilizados na cadeia agroindustrial comercializados pela Devedora. significa os investidores qualificados, assim definidos nos termos do artigo 12 da Resolução CVM 30. significa os investidores profissionais, assim definidos nos termos dos artigos 11 da Resolução CVM 30. Significa o Imposto sobre Operações de Câmbio. significa o Imposto sobre Operações com Títulos e Valores Mobiliários. significa o Índice Nacional de Preços ao Consumidor Amplo, calculado e divulgado pelo Instituto Brasileiro de Geografia e Estatística. significa o Imposto de Renda das Pessoas Jurídicas. significa o Imposto de Renda Retido na Fonte. significa o Imposto sobre Serviços de Qualquer Natureza. significa a Jurisdição de Tributação Favorecida. significa a Junta Comercial do Estado de Minas Gerais. significa a legislação brasileira contra prática de corrupção, atos lesivos à administração pública ou ao patrimônio público nacional, incluindo, sem limitação: (i) Lei n.º 9.613, de 3 de março de 1998, conforme em vigor; (ii) Lei n.º 12.846, de 1º de agosto de 2013, conforme em vigor; (iii) Lei n.º 12.529, de 30 de novembro de 2011, conforme em vigor; (iv) Decreto n.º 8.420, de 18 de março de 2015; (v)\n\n13\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 13, 'filetype': 'application/pdf', 'parent_id': 'b763d09280e40b580598720bf3c3f59a'}),
#  Document(page_content='“Lei das Sociedades por Ações”:\n\n“Lei 5.474”:\n\n“Lei 7.492”:\n\n“Lei 9.514”:\n\n“Lei 11.033”:\n\n“Lei 11.076”:\n\n“Lei 14.430”:\n\n“MDA”:\n\n“Montante Mínimo do Fundo de Despesas”:\n\n“Nota Promissória 001/2023”:\n\n“Nota Promissória 002/2023”:\n\nU.S. Foreign Corrupt Practices Act of 1977; (vi) Organization for Economic Co-operation and Development Convention on Combating Bribery of Foreign Public Officials in International Business Transactions; e (vii) United Kingdom Bribery Act 2010, as portarias e instruções normativas expedidas pela Controladoria-Geral da União nos termos da lei e decreto acima mencionados, bem como todas as leis, regulamentos e demais atos normativos decretos, expedidos por autoridade governamental com jurisdição relacionada a esta matéria. significa a Lei nº 6.404, de 15 de dezembro de 1976, conforme em vigor. significa a Lei nº 5.474, de 18 de julho de 1968, conforme em vigor. significa a Lei nº 7.492, de 16 de junho de 1986, conforme em vigor. significa a Lei nº 9.514, de 20 de novembro de 1997, conforme em vigor. significa a Lei n.º 11.033, de 21 de dezembro de 2004, conforme em vigor. significa a Lei nº 11.076, de 30 de dezembro de 2004, conforme em vigor. significa a Lei nº 14.430, de 03 de agosto de 2022, conforme em vigor. significa o Módulo de Distribuição de Ativos, administrado e operacionalizado pela B3. significa o montante equivalente a R$ 393.397,00 (trezentos e noventa e três mil e trezentos e noventa e sete reais), suficiente para arcar com as Despesas dos 12 (doze) meses. significa a “Nota Promissória nº 001/2023”, identificada no Anexo I, emitida de acordo com o Decreto 2.044, com valor de R$ 7.000.000,00 (sete milhões de reais), por Ederson, em favor da Emitente, em razão de negócios relacionados com a produção e a comercialização de produtos ou insumos agropecuários, nos termos do artigo 23, § 1º, da Lei 11.076, cujos direitos creditórios servem de lastro aos CDCA. significa a “Nota Promissória nº 002/2023”, identificada no Anexo I, emitida de acordo com o Decreto 2.044, com valor de R$ 7.000.000,00 (sete milhões de reais), por Adriano, em favor da Emitente, em razão de negócios relacionados com a produção e a comercialização de produtos ou insumos agropecuários, nos termos do artigo 23, § 1º, da\n\n14\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 14, 'filetype': 'application/pdf', 'parent_id': '4e5fac3205099088cc68522ec6415945'}),
#  Document(page_content='“Nota Promissória 003/2023”:\n\n“Notas Promissórias”:\n\n“Obrigação de Recomposição de Garantia”:\n\nObrigações Garantidas”:\n\nLei 11.076, cujos direitos creditórios servem de lastro aos CDCA. significa a “Nota Promissória nº 003/2023”, identificada no Anexo I, emitida de acordo com o Decreto 2.044, com valor de R$ 7.000.000,00 (sete milhões de reais), por Silvio, em favor da Emitente, em razão de negócios relacionados com a produção e a comercialização de produtos ou insumos agropecuários, nos termos do artigo 23, § 1º, da Lei 11.076, cujos direitos creditórios servem de lastro aos CDCA. significa, quando referidas em conjunto, a Nota Promissória 001/2023, a Nota Promissória 002/2023 e a Nota Promissória 003/2023. significa a obrigação da Devedora de, após cada Retenção, realizada para constituição e/ou recomposição do Fundo de Despesas e/ou do Fundo de Retenção, ou após cada Data de Verificação de Performance, de recompor a garantia de Cessão Fiduciária, ao Valor Mínimo de Garantia mediante a cessão fiduciária de novos Direitos Creditórios em Garantia que atendam aos Critérios de Elegibilidade, em favor da Securitizadora valor correspondente na Conta Centralizadora, conforme disposto no Contrato de Cessão Fiduciária. significa toda e qualquer obrigação, principal e/ou acessória, presente e/ou futura, derivada dos CDCA, observada a vinculação de Direitos Creditórios do Agronegócio de titularidade da Securitizadora e das Garantias aos CRA bem como eventuais custos e/ou despesas incorridos pela Securitizadora, pelo Agente Fiduciário e/ou pelos titulares de CRA, inclusive, mas não se limitando, em razão de atos que tenham que praticar por conta de: (i) inadimplemento, total ou parcial dos CDCA, inclusive com relação a valores de reembolso e/ou para fins de recomposição do Fundo de Despesas e/ou do Fundo de Retenção, Separado; do (ii) decretação de vencimento antecipado de todo e qualquer montante de pagamento, valor nominal do crédito, remuneração, encargos ordinários e/ou de mora, decorrentes dos CDCA; (iii) incidência de tributos e despesas gerais, conforme aplicáveis, inclusive, sem limitação, por força da excussão das Garantias; (iv) consolidação de propriedade das Garantias em nome da Securitizadora ou para excussão das Garantias, inclusive emolumentos e publicação dos anúncios dos leilões, (v) honorários advocatícios, conforme aplicável; e\n\nou mediante\n\ndepósito\n\ndo\n\nintegrantes\n\nPatrimônio\n\n15\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 15, 'filetype': 'application/pdf', 'parent_id': 'b873969de141e8d7bae297ec4b5d2e6f'}),
#  Document(page_content='“Oferta”:\n\n“Opção de Recomposição de Garantia”:\n\n“Opção de Substituição”:\n\n“Operação”:\n\n“Operação de Securitização”\n\n“Ordem de Prioridade de Pagamento”:\n\n“Outros Ativos”:\n\nprocessos, procedimentos e/ou outras medidas judiciais ou extrajudiciais necessários à salvaguarda de direitos e prerrogativas decorrentes dos CDCA, desde que devidamente comprovados. significa a distribuição pública sob rito automático de registro perante a CVM dos CRA, realizada nos termos do artigo 26 e seguintes da Resolução CVM 160 e das demais disposições legais e regulamentares aplicáveis, a qual (i) é destinada exclusivamente a Investidores Profissionais; (ii) será intermediada pelo Coordenador Líder; e (iii) será registrada sob o rito automático de distribuição perante a CVM. significa a opção da Devedora, a ser exercida até 90 (noventa) dias antes da Data de Vencimento, de substituir, total ou parcialmente, os Títulos e/ou os Recebíveis cedidas fiduciariamente nos termos do Contrato de Cessão Fiduciária, que tenham sido quitados, por novos Títulos e/ou Recebíveis que atendam aos Critérios de Elegibilidade, nos termos da Cláusula 5.1 do Contrato de Cessão Fiduciária. significa a opção da Devedora, a ser exercida até 30 de setembro de 2027, de substituir, total ou parcialmente, os Títulos e/ou os Recebíveis: (i) vincendos, apenas nos casos cujas respectivas notas tenham sido canceladas em razão da devolução de Insumos pelos respectivos Clientes, ou (ii) inadimplidos que ainda não tenham sido quitados, cedidos fiduciariamente nos termos do Contrato de Cessão Fiduciária, a qual poderá ocorrer pela substituição por novos Títulos e/ou Recebíveis que atendam aos Critérios de Elegibilidade, nos termos da Cláusula 5.2 e seguintes do Contrato de Cessão Fiduciária, limitada a até 20% (vinte por cento) do Valor Mínimo de Garantia ao ano. significa, quando referidas em conjunto, a Emissão, a Operação de Securitização e a Oferta. significa a operação de securitização a ser realizada pela Securitizadora por meio da emissão dos CRA, os quais terão como lastro, dentre outros direitos creditórios especificados neste Termo de Securitização, os CDCA. significa a ordem de alocação dos recursos oriundos do pagamento dos Direitos Creditórios do Agronegócio, conforme disposto na Cláusula 13 abaixo. significa os títulos federais de emissão do Tesouro Nacional ou do Banco Central do Brasil, certificados de depósito bancário emitidos por Instituições Autorizadas e/ou cotas\n\n16\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 16, 'filetype': 'application/pdf', 'parent_id': '2b44990dbafb9658310475ff07e182b6'}),
# ...
#  Document(page_content='Garantias, o que podem afetar adversamente a capacidade de pagamento dos Direitos Creditórios do Agronegócio e, consequentemente, dos CRA.\n\nRisco relacionado aos instrumentos financeiros identificados no curso da auditoria\n\nA Devedora emitiu outras cédulas de crédito bancário e cédulas de direitos creditórios do agronegócio, tendo os Avalistas como sua garantidora também nestes instrumentos. Na hipótese de eventual inadimplemento da Devedora e/ou dos Avalistas com terceiros, em valor, individual ou agregado, seja igual ou superior a R$ 1.000.000,00 (hum milhão de reais) ou seu equivalente em outras moedas, poderá ser declarado Vencimento Antecipado nos termos da Cláusula 6.2, (xv), dos CDCA, além de impactar adversamente no pagamento dos Direitos Creditórios do Agronegócio e dos CRA.\n\nRiscos Relacionados ao Setor\n\nRiscos Climáticos\n\nAs alterações climáticas extremas podem ocasionar mudanças bruscas nos ciclos produtivos de commodities agrícolas, por vezes gerando choques de oferta, quebras de safra, volatilidade de preços, alteração da qualidade e interrupção no abastecimento dos produtos por elas afetados.\n\nNesse contexto, a capacidade de produção e entrega da Devedora e dos Clientes pode ser adversamente afetada, o que poderá impactar negativamente a capacidade de pagamento dos CRA.\n\nBaixa Produtividade\n\nA falha ou impossibilidade no controle de pragas e doenças pode afetar negativamente a produtividade da lavoura de produtos. A Devedora e os Clientes poderão não obter sucesso no controle de pragas e doenças da lavoura, seja por não aplicar corretamente insumos adequados – defensivos agrícolas – seja por uma nova praga ou doença ainda sem diagnóstico. A produtividade pode ser afetada também pela não utilização da mínima quantidade necessária de fertilizantes devido à flutuação do preço desses insumos, ou pela falta de crédito. Esses impactos podem afetar negativamente a produtividade e qualidade do produto. Adicionalmente, a falha, imperícia ou ineficiência na efetiva aplicação de tais insumos nas lavouras pode afetar negativamente a produtividade da lavoura. Nesse caso, a capacidade da Devedora e dos Clientes poderá estar comprometida, podendo impactar também a capacidade de pagamento dos CRA.\n\nVolatilidade do Preço das Commodities\n\nOs produtos agrícolas são cotados internacionalmente em dólares em bolsas de mercadorias situadas em várias partes do mundo, inclusive no Brasil. A variação dos seus preços pode exercer um grande impacto nos resultados da Devedora, dos Clientes. As flutuações de preços nos produtos são afetadas pela demanda interna e externa, e pelo volume de produção e dos estoques mundiais. A flutuação do seu preço pode ocasionar um grande impacto na rentabilidade\n\n123\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 123, 'filetype': 'application/pdf', 'parent_id': 'f75d00f31f925dcf384dd9d9f5498c2f'}),
#  Document(page_content='da Devedora e dos Clientes se a sua receita com a sua venda estiver abaixo do seu custo de produção, quer seja pelo preço em dólar, quer seja pelo preço em reais. Estes impactos podem comprometer o pagamento dos Títulos e/ou Recebíveis e, consequentemente, comprometer a capacidade de pagamento dos CRA.\n\nVariação Cambial\n\nOs custos, insumos e preços internacionais dos produtos agrícolas sofrem influência da paridade entre moedas internacionais (sobretudo o dólar) e o real. A variação decorrente do descasamento de moedas entre os custos dos insumos em Reais para a Devedora em relação à receita pela venda do produto, que é cotada pelos preços em dólares nas bolsas de Chicago, Nova York e/ou São Paulo, podem impactar negativamente a capacidade de pagamento dos Títulos e/ou Recebíveis. Desta forma, qualquer oscilação no preço de moedas internacionais (sobretudo o Dólar Norte Americano) pode afetar potencialmente os preços e custos de produção dos produtos agrícolas, e, assim, dificultar ou impedir o cumprimento de pagamento dos Clientes, o que, por consequência, pode igualmente causar impacto relevante e adverso nas condições de pagamento das Garantias, que, por sua vez, poderia causar impacto relevante e adverso nas condições de pagamento dos CRA.\n\nRisco de Armazenamento\n\nA armazenagem inadequada dos produtos agrícolas pode ocasionar perdas no preço dos produtos agrícolas decorrentes de: (i) excesso de umidade; (ii) altas temperaturas; (iii) falha nos sistemas de controle do ambiente no armazém; e (iv) falhas no manuseio do produto agrícola. As perdas podem ocorrer por parte da Devedora e dos Clientes. Os riscos dos mesmos impactos poderão ocorrer se a Devedora ou os Clientes mantiverem o produto em bolsões armazenados em suas fazendas. A redução do preço do produto decorrente da armazenagem inadequada poderá afetar negativamente a capacidade de pagamento da Devedora e dos Clientes e, consequentemente, comprometer a capacidade de pagamento dos CRA.\n\nRisco de Transporte\n\nAs deficiências da malha rodoviária, ferroviária ou hidroviária, tais como estradas sem asfalto ou sem manutenção, insuficiência de ferrovias, principalmente nas regiões mais distantes do porto, ocasionam altos custos de logística e, consequentemente, perda da rentabilidade dos produtos agrícolas. Da mesma forma, a falha ou imperícia no manuseio para transporte, seja em trens, caminhões ou embarcações, pode acarretar perdas de produção, desperdício de quantidades ou danos ao produto agrícola. As constantes mudanças climáticas, como excesso de chuva, vêm ocasionando piora no estado de conservação das estradas, o que pode acarretar um aumento de perda de produção acima do previsto. Outra deficiência são os portos, que não conseguem escoar toda produção no período de envio dos produtos agrícolas. Com as filas e a demora na exportação, pode ocorrer quebra de contrato de comercialização dos produtos. Dessa forma, o valor final do produto entregue pode ser inferior ao valor nominal dos Títulos e/ou dos Recebíveis potencialmente afetando, assim, a capacidade de pagamento da Devedora, dos Clientes e, consequentemente, comprometer a capacidade de pagamento dos CRA.\n\n124\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 124, 'filetype': 'application/pdf', 'parent_id': '2422b272f1c28cf697339807fa89f082'}),
#  Document(page_content='Riscos Relacionados à Emissora\n\nA Emissora é dependente de registro de companhia aberta\n\nA Emissora foi constituída com o escopo de atuar como securitizadora de Direitos Creditórios do Agronegócio por meio da emissão de certificados de recebíveis do agronegócio. Para tanto, depende da manutenção de seu registro de companhia aberta junto à CVM e das respectivas autorizações societárias. Caso a Emissora não atenda aos requisitos exigidos pela CVM em relação às companhias abertas, sua autorização poderá ser suspensa ou mesmo cancelada, afetando assim as suas emissões de certificados de recebíveis do agronegócio.\n\nNão realização dos ativos\n\nA Emissora é uma companhia destinada exclusivamente à aquisição e posterior securitização de Direitos Creditórios do Agronegócio, nos termos da Lei 14.430 e da Resolução CVM 60, conforme alteradas, por meio da emissão de certificados de recebíveis do agronegócio e de certificados de recebíveis imobiliários. O Patrimônio Separado da presente Emissão tem como única fonte de recursos os respectivos Direitos Creditórios do Agronegócio, nos termos deste Termo de Securitização. Dessa forma, qualquer atraso ou inadimplência por parte da Devedora, dos Clientes poderá afetar negativamente a capacidade da Securitizadora de honrar os pagamentos devidos aos Titulares de CRA.\n\nNão aquisição de Direitos Creditórios do Agronegócio\n\nA Emissora não possui a capacidade de originar créditos para securitização, sendo suas emissões realizadas com créditos adquiridos de terceiros. Portanto, o sucesso na identificação e realização de parcerias para aquisição de créditos é fundamental para o desenvolvimento de suas atividades.\n\nA Emissora pode ter dificuldades em identificar oportunidades atraentes ou pode não ser capaz de efetuar os investimentos desejados em termos economicamente favoráveis. A falta de acesso a capital adicional em condições satisfatórias pode restringir o crescimento e desenvolvimento e desenvolvimento futuros das atividades da Emissora, o que pode prejudicar sua situação financeira, assim como seus resultados operacionais.\n\nRiscos associados aos Prestadores de Serviços\n\nA Emissora contrata prestadores de serviços terceirizados para a realização de atividades, como auditores, agente fiduciário, agência classificadora de risco, escriturador, dentre outros. Caso alguns destes prestadores de serviços aumentem significantemente seus preços ou não prestem serviços com a qualidade e agilidade esperada pela Emissora, poderá ser necessária a substituição do prestador de serviço. Esta substituição, no entanto, poderá não ser bem-sucedida e afetar adversamente os resultados da Emissora.\n\n125\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 125, 'filetype': 'application/pdf', 'parent_id': '3e907badc63cc776163b198a92874172'}),
#  Document(page_content='Administração\n\nA capacidade da Emissora de manter uma posição competitiva depende em larga escala dos serviços de sua alta administração. Nesse sentido, a Emissora não pode garantir que terá sucesso em atrair e manter pessoal qualificado para integrar sua alta administração. A perda dos serviços de qualquer de seus membros da alta administração ou a incapacidade de atrair e manter pessoal adicional para integrá-la, pode causar um efeito adverso relevante na situação financeira e nos resultados operacionais da Emissora.\n\n126\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 126, 'filetype': 'application/pdf', 'parent_id': '92eeae4fc4490d2f291cb300a23b9963'}),
#  Document(page_content='MANIFESTO DEASSINATURAS\n\nCódigo de validação: 546KQ-TBSM7-VTY3M-6YDA8\n\nDocumento assinado com o uso de certificado digital ICP Brasil, no AssinadorRegistro de Imóveis, pelos seguintes signatários:\n\nFabryny Bittencourt Huller - Testemunha (CPF 032.796.580-04)\n\nAna Carla Moliterno - Testemunha (CPF 297.319.798-83)\n\nRAFAEL CASEMIRO PINTO - Signatário (CPF 112.901.697-80)\n\nGuilherme Rodrigues da Cunha - Signatário (CPF 073.848.326-59)\n\nNilson Raposo Leite - Signatário (CPF 011.155.984-73)\n\nPara verificar as assinaturas, acesse o link direto de validação deste documento:\n\nhttps://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\nOu acesse a consulta de documentos assinados disponível no link abaixo e informeo código de validação:\n\nhttps://assinador.registrodeimoveis.org.br/validate.\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.\n\n', metadata={'source': '573735.pdf', 'coordinates': {'points': ((573.73, 42.52999999999997), (573.73, 745.61), (587.91, 745.61), (587.91, 42.52999999999997)), 'system': 'PixelSpace', 'layout_width': 595, 'layout_height': 842}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 127, 'filetype': 'application/pdf', 'parent_id': 'efd25ed0923d69802fcb83603998915c'})]

# %%
str_template_prompt_initial = \
"""
Responda à pergunta o mais detalhadamente possível a partir do contexto fornecido.
Certifique-se de fornecer todos os detalhes. Quebre as tarefas em pequenas tarefas e passos.
Caso a resposta não estiver no contexto fornecido, basta dizer "a resposta não está disponível no contexto".
Não forneça respostas erradas ou respostas que não estão no contexto fornecido.
Não coloque comentários dentro do JSON retornado para explicar os atributos.

QUESTION: {question}
=========
{summaries}
=========
FINAL ANSWER:
SOURCES:
"""

# %% [markdown]
# # Splitting doc in chuncks using RecursiveCharacterTextSplitter

# %%
# segmenting the document into segments
text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size, chunk_overlap=chunk_overlap,
            separators=["\n\n", "\n", " ", ""])
chunk_docs = text_splitter.split_documents(raw_doc)

# %%
chunk_docs[0]
# Out:
# Document(page_content='TERMO DE SECURITIZAÇÃO DE DIREITOS CREDITÓRIOS DO AGRONEGÓCIO\n\npara emissão de\n\nCERTIFICADOS DE RECEBÍVEIS DO AGRONEGÓCIO DA 1ª E 2ª SÉRIES DA 34ª (TRIGÉSIMA QUARTA) EMISSÃO DA\n\nCERES SECURITIZADORA S.A. como companhia securitizadora\n\nlastreados em direitos creditórios do agronegócio devidos pela NATIVA AGRONEGÓCIOS LTDA.\n\ncelebrado com\n\nOLIVEIRA TRUST DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS S.A. como agente fiduciário\n\nDatado de 18 de dezembro de 2023\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 1, 'filetype': 'application/pdf', 'parent_id': 'efb6bc7732c491d63c9ab702b264530a'})

# %% [markdown]
# # Get Embeddings

# %%
embeddings = AzureOpenAIEmbeddings(model=embedding_model)

# %% [markdown]
# # Saving chunks in local database

# %%
vector_store = FAISS.from_documents(chunk_docs, embedding=embeddings)
vector_store.save_local(path_faiss)

# %% [markdown]
# # Creating Prompt

# %%
def get_schema(campo):
    schema = ResponseSchema(
        name=campo[0],
        type=campo[1],
        description=campo[2]
    )

    return schema

# %%
def create_user_question(campos):
    nomes_campos = [campo[0] for campo in campos]
    
    response_schema = [
        get_schema(campo) for campo in campos
    ]
    
    output_parser = StructuredOutputParser.from_response_schemas(response_schema)
    schema_formatado = output_parser.get_format_instructions()
    
    template = PromptTemplate.from_template(
    """
    Extraia as seguintes informações:
    
    {nomes_campos}
    
    {schema}
    """, partial_variables={'nomes_campos': ', '.join(nomes_campos) ,'schema': schema_formatado})
    
    user_question = template.format()
    print(user_question)
    return output_parser, user_question

# %% [markdown]
# # Retrieving relevants data

# %%
def get_docs_relevants(user_question):
    vector_store_loaded = FAISS.load_local(path_faiss, embeddings, allow_dangerous_deserialization=True)
    
    docs_relevants = vector_store_loaded.similarity_search(user_question, k=k, fetch_k=fetch_k)
    return docs_relevants

# %% [markdown]
# # Question to LLM

# %%
def invoke_llm(user_question, docs_relevants):
    template_prompt_initial = PromptTemplate.from_template(str_template_prompt_initial)
    
    # llm = AzureChatOpenAI(deployment_name=deployment_name, model_name=model, temperature=temperature)
    llm = AzureChatOpenAI(azure_deployment=deployment_name, openai_api_version=openai_api_version,)
    
    chain = load_qa_with_sources_chain(llm=llm, chain_type="stuff", prompt=template_prompt_initial, verbose=verbose)
    
    input_msg = {"input_documents": docs_relevants, "question": user_question}
    
    response = chain.invoke(input_msg, return_only_outputs=True,)

    if "output_text" in response:        
        return response["output_text"]
    else:
        print("Error")
    return None

# %% [markdown]
# # Executing LLM

# %%
from dataclasses import dataclass

@dataclass
class CamposLLM:
    """Class for keeping track of an item in inventory."""
    name: str
    type: str
    description: str
    value: str = ""
    depends_on = []

# %%
# campos = [
#     ("tipo", "str", "Sendo CERTIFICADOS DE RECEBIVEIS DO AGRONEGOCIO = CRA; Sendo CERTIFICADOS DE RECEBIVEIS IMOBILIARIOS = CRI; Sendo DEBENTURES = DEB; Sendo CERTIFICADOS DE RECEBIVEIS = CR; Retorne se CRI, CRA, CR ou DEB. Caso não encontre, retorne ''."),
#     ("numero_emissao", "str", "Número da emissão da Securitizadora. Retorne apenas a forma numérica."),
#     ("numero_serie", "str", "Número da série da emissão. Retorne apenas a forma numérica. Caso seja uma série única, retorne UNI. Caso encontre mais de uma, retorne separados por ','."),
#     ("nome_securitizadora_emissora", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Emissora ou Securitizadora. Caso não encontre retorne ''"),
#     ("nome_agente_fiduciario", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Agente Fiduciário. Caso não encontre retorne ''"),
#     ("nome_devedora", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Devedora ou que deve. Caso não encontre retorne ''. Caso encontre mais de um, retorne separados por ','"),
#     ("nome_avalista_fiadora", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Avalista ou Fiador. Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''"),
#     ("numero_avalista_fiadora", "str", "Número de inscrição no CNPJ do Avalista ou Fiador {nome_avalista_fiadora}. Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''."),
#     ("numero_cnpj_securitizadora_emissora", "str", "Número da inscrição no Cadastro Nacional de Pessoa Jurídica (“CNPJ”) da Emissora ou Securitizadora - {nome_securitizadora_emissora}. Caso não encontre retorne ''"),
#     ("numero_cnpj_agente_fiduciario", "str", "Número da inscrição no Cadastro Nacional de Pessoa Jurídica (“CNPJ”) do Agente Fiduciário - {nome_agente_fiduciario}. Caso não encontre retorne ''"),
#     ("numero_cnpj_devedora", "str", "Número de inscrição no CNPJ da Devedora {nome_devedora}. Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''."),
#     ("nome_cedente", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Cedente(s) ou que cedeu. Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''."),
#     ("numero_cpf_cnpj_cedente", "str", "Número de inscrição no CNPJ ou CPF do(s) Cedente(s). Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''"),
#     ("numero_minimo_instalacao_assembleia_primeira_convocacao", "str", "Número mínimo de presentes para instalação de assembleia em primeira convocação. Caso não encontre retorne ''. Caso encontre, retorne o mais simples possível."),
#     ("numero_minimo_instalacao_assembleia_segunda_convocacao", "str", "Número mínimo de presentes para instalação de assembleia em segunda convocação. Caso não encontre retorne ''. Caso encontre, retorne o mais simples possível.")
# ]

# %%
campos = [
    ("tipo", "str", "Sendo CERTIFICADOS DE RECEBIVEIS DO AGRONEGOCIO = CRA; Sendo CERTIFICADOS DE RECEBIVEIS IMOBILIARIOS = CRI; Sendo DEBENTURES = DEB; Sendo CERTIFICADOS DE RECEBIVEIS = CR; Retorne se CRI, CRA, CR ou DEB. Caso não encontre, retorne ''."),
    ("numero_emissao", "str", "Número da emissão da Securitizadora. Retorne apenas a forma numérica."),
    ("numero_serie", "str", "Número da série da emissão. Retorne apenas a forma numérica. Caso seja uma série única, retorne UNI. Caso encontre mais de uma, retorne separados por ','."),
    ("nome_securitizadora_emissora", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Emissora ou Securitizadora. Caso não encontre retorne ''"),
    ("nome_agente_fiduciario", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Agente Fiduciário. Caso não encontre retorne ''"),
    # ("nome_devedora", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Devedora ou que deve. Caso não encontre retorne ''. Caso encontre mais de um, retorne separados por ','"),
    # ("nome_avalista_fiadora", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Avalista ou Fiador. Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''"),
    # ("numero_avalista_fiadora", "str", "Número de inscrição no CNPJ do Avalista ou Fiador {nome_avalista_fiadora}. Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''."),
    # ("numero_cnpj_securitizadora_emissora", "str", "Número da inscrição no Cadastro Nacional de Pessoa Jurídica (“CNPJ”) da Emissora ou Securitizadora - {nome_securitizadora_emissora}. Caso não encontre retorne ''"),
    # ("numero_cnpj_agente_fiduciario", "str", "Número da inscrição no Cadastro Nacional de Pessoa Jurídica (“CNPJ”) do Agente Fiduciário - {nome_agente_fiduciario}. Caso não encontre retorne ''"),
    # ("numero_cnpj_devedora", "str", "Número de inscrição no CNPJ da Devedora {nome_devedora}. Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''."),
    # ("nome_cedente", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Cedente(s) ou que cedeu. Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''."),
    # ("numero_cpf_cnpj_cedente", "str", "Número de inscrição no CNPJ ou CPF do(s) Cedente(s). Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''"),
    # ("numero_minimo_instalacao_assembleia_primeira_convocacao", "str", "Número mínimo de presentes para instalação de assembleia em primeira convocação. Caso não encontre retorne ''. Caso encontre, retorne o mais simples possível."),
    # ("numero_minimo_instalacao_assembleia_segunda_convocacao", "str", "Número mínimo de presentes para instalação de assembleia em segunda convocação. Caso não encontre retorne ''. Caso encontre, retorne o mais simples possível.")
]

# %%
campos = dict()
campos["nome_devedora"] = CamposLLM("nome_devedora", "str", "Nome ou empresa ou sociedade cuja denominação ou significado está como Devedora ou que deve. Caso não encontre retorne ''. Caso encontre mais de um, retorne separados por ','")
campos = dict()
campos["numero_cnpj_devedora"] = CamposLLM("numero_cnpj_devedora", "str", "Número de inscrição no CNPJ da Devedora {nome_devedora}. Caso encontre mais de um, retorne separados por ','. Caso não encontre retorne ''.")

# %%
def get_campos_to_user_question(campos):
    campos_to_user_question = []
    
    for k, campo in campos.items():
        if campo.value == "" and campo.depends_on == []:
            campos_to_user_question.append(campo)
    
    return campos_to_user_question

# %%
output_parser, user_question = create_user_question(campos)

docs_relevants = get_docs_relevants(user_question)
print(docs_relevants)

output = invoke_llm(user_question, docs_relevants)
output
# Out:
#     Extraia as seguintes informações:
#
#     tipo, numero_emissao, numero_serie, nome_securitizadora_emissora, nome_agente_fiduciario
#
#     The output should be a markdown code snippet formatted in the following schema, including the leading and trailing "```json" and "```":
#
# ```json
# {
# 	"tipo": str  // Sendo CERTIFICADOS DE RECEBIVEIS DO AGRONEGOCIO = CRA; Sendo CERTIFICADOS DE RECEBIVEIS IMOBILIARIOS = CRI; Sendo DEBENTURES = DEB; Sendo CERTIFICADOS DE RECEBIVEIS = CR; Retorne se CRI, CRA, CR ou DEB. Caso não encontre, retorne ''.
# 	"numero_emissao": str  // Número da emissão da Securitizadora. Retorne apenas a forma numérica.
# 	"numero_serie": str  // Número da série da emissão. Retorne apenas a forma numérica. Caso seja uma série única, retorne UNI. Caso encontre mais de uma, retorne separados por ','.
# 	"nome_securitizadora_emissora": str  // Nome ou empresa ou sociedade cuja denominação ou significado está como Emissora ou Securitizadora. Caso não encontre retorne ''
# 	"nome_agente_fiduciario": str  // Nome ou empresa ou sociedade cuja denominação ou significado está como Agente Fiduciário. Caso não encontre retorne ''
# }
# ```
#
# [Document(page_content='“Custodiante”:\n\n“CVM”:\n\n“Data de Emissão”:\n\n“Data de Integralização dos CRA”:\n\n“Data de Pagamento da Remuneração dos CRA”\n\n“Data de Vencimento”:\n\n“Data de Vencimento dos Direitos Creditórios do Agronegócio”\n\n“Data Limite de Constituição”:\n\n“Datas de Verificação de Performance”:', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 9, 'filetype': 'application/pdf', 'parent_id': 'c101f4dea75a329395fb7fc9546505a3'}), Document(page_content='“CETIP21”:\n\n“Clientes”:\n\n“CNPJ”:\n\n“Código ANBIMA”:\n\n“Código Civil”:\n\n“Código de Processo Civil”:\n\n“COFINS”:\n\n“Condições Precedentes”:\n\n“Condições Precedente de Desembolso”:\n\n“Condições Precedentes de Aquisição”:\n\n“Conta Autorizada Devedora”:\n\n“Conta Centralizadora”:', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 6, 'filetype': 'application/pdf', 'parent_id': 'b4e3e013666393b61d9126f128ff5494'}), Document(page_content='(ix)\n\nopinar sobre a suficiência das informações prestadas nas propostas de modificações nas condições dos CRA;\n\n(x)\n\nsolicitar, quando julgar necessário para o fiel desempenho de suas funções, certidões atualizadas dos distribuidores cíveis, das Varas de Fazenda Pública, cartórios de protesto, das Varas do Trabalho, Procuradoria da Fazenda Pública ou outros órgãos pertinentes, onde se localiza o domicílio ou a sede do estabelecimento principal da Emissora, da Devedora e/ou dos Avalistas;\n\n55\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 55, 'filetype': 'application/pdf', 'parent_id': 'b488b0e2bcd5d9ef24c8f73d21f53152'}), Document(page_content='“Emissão”:\n\n“Emissora” ou “Securitizadora”:\n\n“Empresa de Auditoria”\n\n“Escriturador”:\n\n“Eventos de Liquidação do Patrimônio Separado”:\n\n“Fundo de Despesas”:\n\n“Fundo de Retenção”:', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 12, 'filetype': 'application/pdf', 'parent_id': '51979e6606bc3fdb89e5016aef8b5366'}), Document(page_content='(li)\n\ndivulgar a ocorrência de fato relevante, conforme definido pelo artigo 2º da Resolução CVM 44;\n\n(lii)\n\nfornecer as informações solicitadas pela CVM;\n\n51\n\nDocumento assinado no Assinador Registro de Imóveis. Para validar o documento e suas assinaturas acesse https://assinador.registrodeimoveis.org.br/validate/546KQ-TBSM7-VTY3M-6YDA8.', metadata={'source': '573735.pdf', 'coordinates': {'points': ((590.85, 42.51999999999998), (590.85, 695.72), (605.03, 695.72), (605.03, 42.51999999999998)), 'system': 'PixelSpace', 'layout_width': 612.12, 'layout_height': 792.12}, 'filename': '573735.pdf', 'languages': ['eng'], 'last_modified': '2024-09-09T08:37:44', 'page_number': 51, 'filetype': 'application/pdf', 'parent_id': 'fae ...
# '```json\n{\n\t"tipo": "CRA",\n\t"numero_emissao": "",\n\t"numero_serie": "",\n\t"nome_securitizadora_emissora": "",\n\t"nome_agente_fiduciario": ""\n}\n```'

# %%
response_json = output_parser.parse(output)
response_json

# %%
campos_enabled = ['numero_minimo_instalacao_assembleia_primeira_convocacao', 'numero_minimo_instalacao_assembleia_segunda_convocacao']
campos_filtered = [c for c in campos if response_json[c[0]] == '' and c[0] in campos_enabled]

output_parser, user_question = create_user_question(campos_filtered)

docs_relevants = get_docs_relevants(user_question)

output = invoke_llm(user_question, docs_relevants)
response_json2 = output_parser.parse(output)
response_json2
# Out:
# {'numero_minimo_instalacao_assembleia_primeira_convocacao': '50% + 1',
#  'numero_minimo_instalacao_assembleia_segunda_convocacao': 'qualquer número'}
