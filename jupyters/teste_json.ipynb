# %%
import pandas as pd

# %%
path = '/home/alexandre_pantalena/Downloads/CRI_CRA_FixedIncomeCRIInstrumentFileV2_20241024_1.json'

df = pd.read_json(path)
df
# Out:
#            RptDt    TckrSymb SctyId SctySrc MktIdrCd          ISIN  \
# 0     2024-10-24  05J0024381   4771       T       B3  BRBSCSCRI0W3
# 1     2024-10-24  05J0024391   4769       T       B3  BRBSCSCRI0V5
# 2     2024-10-24  07F0006634   4772       T       B3  BRBSCSCRI1U5
# 3     2024-10-24  07F0006635   4770       T       B3  BRBSCSCRI1T7
# 4     2024-10-24  07I0012088   4774       T       B3  BRBSCSCRI1X9
# ...          ...         ...    ...     ...      ...           ...
# 3721  2024-10-24  24J2347143  12281       T       B3  BRRBRACRIQ20
# 3722  2024-10-24  24J2347147  12287       T       B3  BRRBRACRIQ38
# 3723  2024-10-24  24J2417849  12313       T       B3  BRRBRACR0079
# 3724  2024-10-24  24J2479385  12333       T       B3  BRRBRACRIQ46
# 3725  2024-10-24  24J2479470  12334       T       B3  BRRBRACRIQ53
#
#                                          CrpnNm  CrdnlNb  IssdQty      RegnDt  \
# 0     BRAZILIAN SECURITIES CIA DE SECURITIZACAO        1      685  2008-07-18
# ...

# %%
path = '/home/alexandre_pantalena/Downloads/inf_mensal_cri_2024-2024-10-13/inf_mensal_cri_classe_2024.csv'

df = pd.read_csv(path, sep=';', encoding='latin1')
df
# Out:
#             CNPJ_Emissora Codigo_Identificacao_Certificado Data_Referencia  \
# 0      02.105.040/0001-23                       14G0412569      2024-01-01
# 1      02.105.040/0001-23                       14G0412569      2024-01-01
# 2      02.105.040/0001-23                       14G0412569      2024-02-01
# 3      02.105.040/0001-23                       14G0412569      2024-02-01
# 4      02.105.040/0001-23                       14G0412569      2024-03-01
# ...                   ...                              ...             ...
# 28826  51.319.586/0001-92                     BRRCKSCRI015      2024-04-01
# 28827  51.319.586/0001-92                     BRRCKSCRI015      2024-05-01
# 28828  51.319.586/0001-92                     BRRCKSCRI015      2024-06-01
# 28829  51.319.586/0001-92                     BRRCKSCRI015      2024-07-01
# 28830  51.319.586/0001-92                     BRRCKSCRI015      2024-08-01
#
# ...

# %%
df['Classe'].unique()

# 'classe': ['cnpj_emissora', 'codigo_identificacao_certificado', 'data_referencia', 'versao', 'classe'],
# Out:
# array(['Sênior', 'Subordinada', 'Mezanino'], dtype=object)

# %%
df[df['Codigo_CETIP'] == '24G1888841']
# Out:
#             CNPJ_Emissora Codigo_Identificacao_Certificado Data_Referencia  \
# 28813  48.415.978/0001-40                     BRLSECCRI169      2024-08-01
#
#        Versao  Classe  Numero_Serie    Tipo_Oferta Codigo_CETIP   Codigo_ISIN  \
# 28813       1  Sênior             1  Profissionais   24G1888841  BRLSECCRI169
#
#        Quantidade  ...  Quantidade_Certificados Valor_Certificados  \
# 28813         NaN  ...                   9000.0         8875578.04
#
#        Rendimentos Amortizacoes  Rentabilidade Classificacao_Risco_Atual  \
# 28813     26242.65    175600.46           0.02                       NaN
#
#       Nivel_Subordinacao Periodicidade_Amortizacao  \
# 28813                NaN                       NaN
#
#        Indice_Subordinacao_Minimo  Indice_Subordinacao_Data_Base
# 28813                         0.0                            0.0
#
# [1 rows x 28 columns]

# %%
df[df['Codigo_Identificacao_Certificado'] == 'BRLSECCRI169']
# Out:
#             CNPJ_Emissora Codigo_Identificacao_Certificado Data_Referencia  \
# 28813  48.415.978/0001-40                     BRLSECCRI169      2024-08-01
# 28814  48.415.978/0001-40                     BRLSECCRI169      2024-08-01
#
#        Versao  Classe  Numero_Serie    Tipo_Oferta Codigo_CETIP   Codigo_ISIN  \
# 28813       1  Sênior             1  Profissionais   24G1888841  BRLSECCRI169
# 28814       1  Sênior             2  Profissionais   24G1944447  BRLSECCRI177
#
#        Quantidade  ...  Quantidade_Certificados Valor_Certificados  \
# 28813         NaN  ...                   9000.0         8875578.04
# 28814         NaN  ...                   4000.0         3944701.35
#
#        Rendimentos Amortizacoes  Rentabilidade Classificacao_Risco_Atual  \
# 28813     26242.65    175600.46           0.02                       NaN
# 28814     11663.40     78044.65           0.02                       NaN
#
#       Nivel_Subordinacao Periodicidade_Amortizacao  \
# ...
